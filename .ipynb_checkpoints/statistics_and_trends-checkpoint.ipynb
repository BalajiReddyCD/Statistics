# %% [markdown]
# # World Top Companies: Key Financial Analysis

# %%
#importing necessary libraries
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %%
#Reading CSV files using pandas
yield_df     = pd.read_csv("C:\\Users\\BALA\\OneDrive - University of Hertfordshire\\Desktop\\Applied DataScience1\\Assignment 2 statistics and trends\\World Top Companies Key Financial Analysis\\Companies_ranked_by_Dividend_Yield.csv")
earnings_df  = pd.read_csv("C:\\Users\\BALA\\OneDrive - University of Hertfordshire\\Desktop\\Applied DataScience1\\Assignment 2 statistics and trends\\World Top Companies Key Financial Analysis\\Companies_ranked_by_Earnings.csv")
marketcap_df = pd.read_csv("C:\\Users\\BALA\\OneDrive - University of Hertfordshire\\Desktop\\Applied DataScience1\\Assignment 2 statistics and trends\\World Top Companies Key Financial Analysis\\Companies_ranked_by_Market_Cap.csv")
peratio_df   = pd.read_csv("C:\\Users\\BALA\\OneDrive - University of Hertfordshire\\Desktop\\Applied DataScience1\\Assignment 2 statistics and trends\\World Top Companies Key Financial Analysis\\Companies_ranked_by_P_E_ratio.csv")
revenue_df   = pd.read_csv("C:\\Users\\BALA\\OneDrive - University of Hertfordshire\\Desktop\\Applied DataScience1\\Assignment 2 statistics and trends\\World Top Companies Key Financial Analysis\\Companies_ranked_by_Revenue.csv")

# %%
# Merging datasets on 'Name' column
# Merging datasets with suffixes to handle overlapping column names
merged_df1 = pd.merge(yield_df, earnings_df, on='Name', suffixes=('_yield', '_earnings'))
merged_df2 = pd.merge(merged_df1, marketcap_df, on='Name', suffixes=('', '_marketcap'))
merged_df3 = pd.merge(merged_df2, peratio_df, on='Name', suffixes=('', '_peratio'))
merged_df  = pd.merge(merged_df3, revenue_df, on='Name', suffixes=('', '_revenue'))
merged_df
# Out:
#        Rank_yield                     Name Symbol_yield  dividend_yield_ttm  \
# 0               1                  LianBio         LIAN            300940.0
# 1               2           Richter Gedeon       RIG2.F            150430.0
# 2               3              Delek Group     DLEKG.TA            117114.0
# 3               4  LMP Automotive Holdings         LMPX            106250.0
# 4               5                     MBIA          MBI             22346.4
# ...           ...                      ...          ...                 ...
# 9997         9908       Lite-On Technology      2301.TW                 0.0
# 9998         9909          Zensho Holdings       7550.T                 0.0
# 9999         9910          BKV Corporation          BKV                 0.0
# 10000        9911              BioAge Labs         BIOA                 0.0
# 10001        9912         Legacy Education         LGCY                 0.0
#
#        price (GBP)_yield  country_yield  Rank_earnings Symbol_earnings  \
# 0               0.243065  United States           8987            LIAN
# 1              23.726825        Hungary           2210          RIG2.F
# 2              87.735884         Israel           1209        DLEKG.TA
# 3               0.121914  United States           6837            LMPX
# 4               2.727817  United States           9761             MBI
# ...                  ...            ...            ...             ...
# 9997            2.366853         Taiwan           1961         2301.TW
# 9998           42.447877          Japan           2624          7550.T
# 9999           13.867596  United States           8871             BKV
# 10000          16.679304  United States           8632            BIOA
# 10001           3.466385  United States           6505            LGCY
#
#        earnings_ttm  price (GBP)_earnings  ... Rank_peratio  Symbol_peratio  \
# 0     -8.710700e+07              0.243065  ...         8165            LIAN
# 1      4.465570e+08             23.726825  ...         2685          RIG2.F
# 2      1.084660e+09             87.735884  ...         7452        DLEKG.TA
# 3      1.175030e+06              0.121914  ...         5539            LMPX
# 4     -6.630000e+08              2.727817  ...         5883             MBI
# ...             ...                   ...  ...          ...             ...
# 9997   5.436000e+08              2.366853  ...         2111         2301.TW
# 9998   3.223280e+08             42.447877  ...         9910          7550.T
# 9999  -7.321100e+07             13.867596  ...         9911             BKV
# 10000 -5.035200e+07             16.679304  ...         9912            BIOA
# 10001  6.661800e+06              3.466385  ...         3318            LGCY
#
#       pe_ratio_ttm  price (GBP)_peratio  country_peratio Rank_revenue  \
# 0        -0.403797             0.243065    United States         9493
# 1        20.707700            23.726825          Hungary         2355
# 2       -27.898300            87.735884           Israel         2481
# 3        -0.150943             0.121914    United States         6179
# 4        -0.710317             2.727817    United States         9897
# ...            ...                  ...              ...          ...
# 9997     15.908900             2.366853           Taiwan         2047
# 9998    275.203000            42.447877            Japan         1528
# 9999    -12.410500            13.867596    United States         4967
# 10000     0.000000            16.679304    United States         9878
# 10001    28.461400             3.466385    United States         8261
#
#        Symbol_revenue revenue_ttm  price (GBP)_revenue  country_revenue
# 0                LIAN           0             0.243065    United States
# 1              RIG2.F  3435019066            23.726825          Hungary
# 2            DLEKG.TA  3144217178            87.735884           Israel
# 3                LMPX   318486368             0.121914    United States
# 4                 MBI   -48000000             2.727817    United States
# ...               ...         ...                  ...              ...
# 9997          2301.TW  4367274225             2.366853           Taiwan
# 9998           7550.T  6587771160            42.447877            Japan
# 9999              BKV   662392000            13.867596    United States
# 10000            BIOA           0            16.679304    United States
# 10001            LGCY    41698381             3.466385    United States
#
# [10002 rows x 26 columns]

# %%
#Summary of basic statistics
merged_df.describe()
# Out:
#          Rank_yield  dividend_yield_ttm  price (GBP)_yield  Rank_earnings  \
# count  10002.000000        10002.000000       10002.000000   10002.000000
# mean    4953.107678          240.676406          53.084918    4977.708758
# std     2865.472913         3744.559504         358.179996    2865.035942
# min        1.000000            0.000000           0.000000       1.000000
# 25%     2471.250000            0.000000           1.995301    2501.250000
# 50%     4956.500000            0.000000           8.551325    4986.500000
# 75%     7441.750000          235.722000          28.718139    7456.750000
# max     9912.000000       300940.000000       16549.695004    9912.000000
#
#        earnings_ttm  price (GBP)_earnings          Rank     marketcap  \
# count  1.000200e+04          10002.000000  10002.000000  1.000200e+04
# mean   7.003138e+08             53.085417   4956.898920  8.685792e+09
# std    4.187056e+09            358.180352   2860.114416  5.764892e+10
# min   -1.730700e+10              0.000000      1.000000  0.000000e+00
# 25%   -4.913750e+06              1.995301   2471.250000  2.179599e+08
# 50%    5.194340e+07              8.551325   4941.500000  1.078124e+09
# 75%    3.536832e+08             28.718139   7426.750000  4.669933e+09
# max    2.283780e+11          16549.695004   9912.000000  2.689903e+12
#
#         price (GBP)  Rank_peratio  pe_ratio_ttm  price (GBP)_peratio  \
# count  10002.000000  10002.000000  1.000200e+04         10002.000000
# mean      53.085337   4965.712657 -3.233207e+14            53.084960
# std      358.179950   2867.160951  4.936950e+16           358.180008
# min        0.000000      1.000000 -4.677980e+18             0.000000
# 25%        1.995301   2471.250000 -5.152258e-01             1.995301
# 50%        8.551325   4971.500000  9.215295e+00             8.551325
# 75%       28.718139   7471.750000  2.495200e+01            28.718139
# max    16549.695004   9912.000000  1.573740e+18         16549.695004
#
#        Rank_revenue   revenue_ttm  price (GBP)_revenue
# count  10002.000000  1.000200e+04         10002.000000
# mean    4980.805639  5.600718e+09            53.085314
# std     2866.132425  2.289820e+10           358.180190
# min        1.000000 -3.922776e+10             0.000000
# 25%     2501.250000  1.136791e+08             1.995301
# 50%     4986.500000  6.564028e+08             8.551325
# 75%     7471.750000  3.108066e+09            28.718139
# max     9912.000000  6.650350e+11         16549.695004

# %%
# Selecting top 10 companies by dividend yield, earnings, revenue, market_cap and pe_ratio
top_10_companies_yield = yield_df.nlargest(10, "dividend_yield_ttm")
top_10_companies_earnings = earnings_df.nlargest(10, "earnings_ttm")
top_10_companies_revenue = revenue_df.nlargest(10, "revenue_ttm")
top_10_companies_marketcap = marketcap_df.nlargest(10, "marketcap")
top_10_companies_pe_ratio = peratio_df.nlargest(10, "pe_ratio_ttm")
top_10_companies_revenue
# Out:
#    Rank                Name     Symbol   revenue_ttm  price (GBP)  \
# 0     1             Walmart        WMT  665035000000    61.029186
# 1     2              Amazon       AMZN  604334000000   143.454209
# 2     3        Saudi Aramco    2222.SR  495354806850     5.505405
# 3     4             Sinopec  600028.SS  435696880608     0.748295
# 4     5          PetroChina  601857.SS  429671599508     0.969769
# 5     6  Berkshire Hathaway      BRK-B  402877000000   347.537576
# 6     7               Apple       AAPL  385603000000   176.706906
# 7     8        UnitedHealth        UNH  381255000000   441.487244
# 8     9          CVS Health        CVS  363248000000    47.729174
# 9    10          Volkswagen    VOW3.DE  350679303398    79.995895
#
#          country
# 0  United States
# 1  United States
# 2   Saudi Arabia
# 3          China
# 4          China
# 5  United States
# 6  United States
# 7  United States
# 8  United States
# 9        Germany

# %% [markdown]
# # Visualization 1
# ### Bar Plots with Heatmap

# %%
# Function to create a heatmap for the correlation between key metrics
def plot_correlation_heatmap(merged_df):
    plt.figure(figsize=(8, 6))  # Adjusting the figure size for the heatmap
    metrics_df = merged_df[['dividend_yield_ttm', 'earnings_ttm', 'revenue_ttm', 'marketcap', 'pe_ratio_ttm']].corr()
    sns.heatmap(metrics_df, annot=True, cmap='coolwarm')
    plt.title('Correlation Heatmap of Financial Metrics')
    plt.xlabel('Metrics', fontsize=12)
    plt.ylabel('Metrics', fontsize=12)

    plt.savefig("Heatmap.png")  # Save the bar plot figure

# Plotting the heatmap
plot_correlation_heatmap(merged_df)

# %% [markdown]
# # Visualization 2
# ### Scatter Plots

# %%
# Map countries to unique integer codes
top_10_companies_revenue['Country_Code'] = top_10_companies_revenue['country'].astype('category').cat.codes

# %%
import matplotlib.pyplot as plt

# Function to create a scatter plot for Revenue vs Market Cap
def plot_revenue_vs_market_cap(top_10_companies_revenue, top_10_companies_marketcap):
    fig, ax = plt.subplots(figsize=(10, 6))  # figure size

    # Creating the scatter plot
    sc = ax.scatter(
        top_10_companies_revenue['revenue_ttm'],
        top_10_companies_marketcap['marketcap'],
        c=top_10_companies_revenue['Country_Code'],  # Color by country code
        cmap='plasma',  # Color map for distinguishing countries
        s=100  # Size of the points
    )

    # Set titles and labels
    ax.set_title('Revenue vs Market Cap', fontsize=16)
    ax.set_xlabel('Revenue (TTM)', fontsize=12)
    ax.set_ylabel('Market Cap ($B)', fontsize=12)

    # Adding a color bar to indicate the countries
    cbar = fig.colorbar(sc, ax=ax, orientation='vertical', fraction=0.05, pad=0.02)
    cbar.set_label('Country', fontsize=12)
    cbar.set_ticks(range(len(top_10_companies_revenue['Country_Code'].unique())))
    cbar.set_ticklabels(top_10_companies_revenue['Country_Code'].unique()) 

    # Showing grid lines
    ax.grid(True, linestyle='--', alpha=0.7)

    # Saving the plot
    plt.tight_layout()
    plt.savefig("revenue_vs_market_cap.png")
    plt.show()

# Calling the function to create the scatter plot
plot_revenue_vs_market_cap(top_10_companies_revenue, top_10_companies_marketcap)

# %% [markdown]
# # Visualization 3
# ### Histogram plots

# %%
# Grouping by Country and calculating average's
average_yield = yield_df.groupby('Name')['dividend_yield_ttm'].mean().reset_index()
average_earnings = earnings_df.groupby('Name')['earnings_ttm'].mean().reset_index()
average_marketcap = marketcap_df.groupby('Name')['marketcap'].mean().reset_index()
average_revenue = revenue_df.groupby('Name')['revenue_ttm'].mean().reset_index()

# %%
# Sorting by average in descending order and selecting the top 10
top_10_countries1 = average_yield.sort_values(by='dividend_yield_ttm', ascending=False).head(10)
top_10_countries2 = average_earnings.sort_values(by='earnings_ttm', ascending=False).head(10)
top_10_countries3 = average_marketcap.sort_values(by='marketcap', ascending=False).head(10)
top_10_countries4 = average_revenue.sort_values(by='revenue_ttm', ascending=False).head(10)

# %%
# Preparing the data for plotting
countries = top_10_countries1['Name']

average_yields  = top_10_countries1['dividend_yield_ttm']
average_earning = top_10_countries2['earnings_ttm']
average_market  = top_10_countries3['marketcap']
average_revenue = top_10_countries4['revenue_ttm']

# %%
# Function to create a single histogram chart for average financial metrics by country
def plot_average_metrics(countries, average_yields, average_earning, average_market, average_revenue):
    # Setting the figure size
    fig, ax = plt.subplots(figsize=(12, 8))

    # Defining the bar width and positions for each metric
    bar_width = 0.2
    index = np.arange(len(countries))  # The x locations for the groups

    # Creating bars for each metric
    bars1 = ax.bar(index, average_yields, bar_width, label='Average Dividend Yield (%)', color='skyblue')
    bars2 = ax.bar(index + bar_width, average_earning, bar_width, label='Average Earnings', color='green')
    bars3 = ax.bar(index + 2 * bar_width, average_market, bar_width, label='Average Market Cap ($B)', color='lightcoral')
    bars4 = ax.bar(index + 3 * bar_width, average_revenue, bar_width, label='Average Revenue ($B)', color='salmon')

    # Setting the title and labels
    ax.set_title('Average Financial Metrics by Country', fontsize=16)
    ax.set_xlabel('Countries', fontsize=12)
    ax.set_ylabel('Values', fontsize=12)
    ax.set_xticks(index + 1.5 * bar_width)  # Set x-ticks to the center of grouped bars
    ax.set_xticklabels(countries, rotation=45)  # Rotate x-tick labels for better readability

    # Adding grid lines
    ax.grid(axis='y', linestyle='--', alpha=0.7)

    # Adding a legend
    ax.legend()

    # Adjusting layout to prevent overlap
    plt.tight_layout()
    
    # Saving the figure
    plt.savefig("combined_histogram.png")
    plt.show()

# Calling the function to create the combined histogram chart
plot_average_metrics(countries, average_yields, average_earning, average_market, average_revenue)

# %% [markdown]
# # Visualization 4
# ### Pie Charts

# %%
# Function to create a pie chart for revenue distribution
def plot_revenue_distribution(ax, revenues, labels):
    ax.pie(
        revenues,
        labels=labels,
        autopct='%1.1f%%',  # Format for percentage display
        colors=sns.color_palette("Set3")  # Color palette for the pie chart
    )
    ax.set_title('Revenue Distribution by Company')  # Title for the pie chart

# Main function to create the revenue distribution chart
def create_revenue_distribution_chart(top_10_companies_revenue):
    fig, ax = plt.subplots(figsize=(8, 8))  # Create a single subplot

    # Calling the plotting function for the revenue distribution
    plot_revenue_distribution(ax, top_10_companies_revenue['revenue_ttm'], top_10_companies_revenue['Name'])

    plt.tight_layout()  # Adjust layout
    plt.savefig("revenue_distribution_pie_chart.png")  # Save the pie chart figure
    plt.show()  # Show the pie chart

# Calling the function to create the revenue distribution chart
create_revenue_distribution_chart(top_10_companies_revenue)
